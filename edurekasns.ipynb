# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
read1=pd.read_csv("E:\DATASETS\gate_applicants1.csv")

# %% [markdown]
# # Basics

# %%
read1.describe()
# Out:
#            Sr.No        Applied       Appeared         Year
# count  70.000000      70.000000      70.000000    70.000000
# mean   34.500000   40332.471429   33952.557143  2017.357143
# std    20.351085   64471.664073   54706.543653     1.263027
# min     0.000000     906.000000     719.000000  2016.000000
# 25%    17.250000    3557.750000    2954.750000  2016.000000
# 50%    34.500000    8727.500000    7165.000000  2017.000000
# 75%    51.750000   19857.750000   16106.250000  2019.000000
# max    69.000000  234727.000000  197789.000000  2019.000000

# %%
read1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  70 non-null     int64
#  1   Paper Code  70 non-null     object
#  2   Paper Name  70 non-null     object
#  3   Applied     70 non-null     int64
#  4   Appeared    70 non-null     int64
#  5   Year        70 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 3.4+ KB

# %%
read1.head()
# Out:
#    Sr.No Paper Code                  Paper Name  Applied  Appeared  Year
# 0      0         AE       Aerospace Engineering     4639      3697  2019
# 1      1         AG    Agricultural Engineering     2088      1848  2019
# 2      2         AR   Architecture and Planning    11208      9105  2019
# 3      3         BT               Biotechnology    11295      9348  2019
# 4      4         CE           Civil Engineering   170999    145064  2019

# %%
read1.tail()
# Out:
#     Sr.No Paper Code                             Paper Name  Applied  \
# 65     65         PH                                Physics    12243
# 66     66         PI  Production and Industrial Engineering     4131
# 67     67         TF  Textile Engineering and Fibre Science     1587
# 68     68         XE                   Engineering Sciences     3722
# 69     69         XL                          Life Sciences    12791
#
#     Appeared  Year
# 65      9910  2016
# 66      3378  2016
# 67      1406  2016
# 68      3074  2016
# 69     10298  2016

# %%
read1.shape  

# 70 rows , 6 columns
# Out:
# (70, 6)

# %%
read1.columns

# display all the columns
# Out:
# Index(['Sr.No', 'Paper Code', 'Paper Name', 'Applied', 'Appeared', 'Year'], dtype='object')

# %%
read1.nunique()

# unique values
# Out:
# Sr.No         70
# Paper Code    48
# Paper Name    47
# Applied       70
# Appeared      70
# Year           3
# dtype: int64

# %%
read1['Paper Name'].unique()

# Column's Unique Values
# Out:
# array([' Aerospace Engineering', ' Agricultural Engineering',
#        ' Architecture and Planning', ' Biotechnology',
#        ' Civil Engineering', ' Chemical Engineering',
#        ' Computer Science and Information Technology', ' Chemistry',
#        ' Electronics and Communication Engineering',
#        ' Electrical Engineering', ' Ecology and Evolution',
#        ' Geology and Geophysics', ' Instrumentation Engineering',
#        ' Mathematics', ' Mechanical Engineering', ' Mining Engineering',
#        ' Metallurgical Engineering', ' Petroleum Engineering', ' Physics',
#        ' Production and Industrial Engineering', ' Statistics',
#        ' Textile Engineering and Fibre Science', ' Engineering Sciences',
#        ' Life Sciences', 'Aerospace Engineering',
#        'Agricultural Engineering', 'Architecture and Planning',
#        'Biotechnology', 'Civil Engineering', 'Chemical Engineering',
#        'Computer Science and Information Technology', 'Chemistry',
# ...

# %%
read1['Applied'].unique()
# Out:
# array([  4639,   2088,  11208,  11295, 170999,  18783, 124984,  27800,
#        126148, 132294,   1460,   7100,  12289,  13415, 198841,   3179,
#          4456,   2428,  20216,   3503,   1890,   2093,   4431,  22077,
#          5335,   1749,   6661,   9361, 147012,  17329, 116754,  18778,
#        171160, 135426,    906,   6444,  15570,   8094, 217835,   2426,
#          4167,   1964,  13442,   3457,   1658,   3783,  12886,   4418,
#          1595,   6806,  11161, 138147,  18642, 131803,  18434, 183152,
#        146293,    981,   6864,  18045,   7917, 234727,   2753,   4475,
#          2773,  12243,   4131,   1587,   3722,  12791], dtype=int64)

# %%
read1.isnull().sum()

# null values
# Out:
# Sr.No         0
# Paper Code    0
# Paper Name    0
# Applied       0
# Appeared      0
# Year          0
# dtype: int64

# %% [markdown]
# # Data Cleaning & Visualization

# %%
new=read1.drop(['Paper Code','Applied'],axis=1)

# %%
new.head()
# Out:
#    Sr.No                  Paper Name  Appeared  Year
# 0      0       Aerospace Engineering      3697  2019
# 1      1    Agricultural Engineering      1848  2019
# 2      2   Architecture and Planning      9105  2019
# 3      3               Biotechnology      9348  2019
# 4      4           Civil Engineering    145064  2019

# %%
new.describe()
# Out:
#            Sr.No       Appeared         Year
# count  70.000000      70.000000    70.000000
# mean   34.500000   33952.557143  2017.357143
# std    20.351085   54706.543653     1.263027
# min     0.000000     719.000000  2016.000000
# 25%    17.250000    2954.750000  2016.000000
# 50%    34.500000    7165.000000  2017.000000
# 75%    51.750000   16106.250000  2019.000000
# max    69.000000  197789.000000  2019.000000

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Sr.No       70 non-null     int64
#  1   Paper Name  70 non-null     object
#  2   Appeared    70 non-null     int64
#  3   Year        70 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.3+ KB

# %%
corelation=new.corr()

# %%
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)

# %%
sns.pairplot(new)

# %%
sns.relplot(x='Applied',y='Appeared',hue='Paper Name',data=read1)

# %%
sns.distplot(new['Appeared'])

# %%
sns.distplot(read1['Applied'])

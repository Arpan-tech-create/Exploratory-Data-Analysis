# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
read1=pd.read_csv('E:\PY\pandas\FIFA - 1962.csv')
print(read1)
# Out:
#     Position            Team  Games Played  Win  Draw  Loss  Goals For  \
# 0          1          Brazil             6    5     1     0         14
# 1          2  Czechoslovakia             6    3     1     2          7
# 2          3           Chile             6    4     0     2         10
# 3          4      Yugoslavia             6    3     0     3         10
# 4          5         Hungary             4    2     1     1          8
# 5          6    Soviet Union             4    2     1     1          9
# 6          7    West Germany             4    2     1     1          4
# 7          8         England             4    1     1     2          5
# 8          9           Italy             3    1     1     1          3
# 9         10       Argentina             3    1     1     1          2
# 10        11          Mexico             3    1     0     2          3
# 11        12           Spain             3    1     0     2          2
# 12        13         Uruguay             3    1     0     2          4
# 13        14        Colombia             3    0     1     2          5
# 14        15        Bulgaria             3    0     1     2          1
# 15        16     Switzerland             3    0     0     3          2
#
#     Goals Against Goal Difference  Points
# 0               5               9      11
# 1               7               0       7
# 2               8               2       8
# 3               7               3       6
# 4               3               5       5
# 5               7               2       5
# 6               2               2       5
# 7               6              −1       3
# 8               2               1       3
# 9               3              −1       3
# 10              4              −1       2
# 11              3              −1       2
# 12              6              −2       2
# 13             11              −6       1
# 14              7              −6       1
# 15              8              −6       0

# %%
print(read1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Position         16 non-null     int64
#  1   Team             16 non-null     object
#  2   Games Played     16 non-null     int64
#  3   Win              16 non-null     int64
#  4   Draw             16 non-null     int64
#  5   Loss             16 non-null     int64
#  6   Goals For        16 non-null     int64
#  7   Goals Against    16 non-null     int64
#  8   Goal Difference  16 non-null     object
#  9   Points           16 non-null     int64
# dtypes: int64(8), object(2)
# memory usage: 1.4+ KB
# None

# %%
print(read1.head(5))
# Out:
#    Position            Team  Games Played  Win  Draw  Loss  Goals For  \
# 0         1          Brazil             6    5     1     0         14
# 1         2  Czechoslovakia             6    3     1     2          7
# 2         3           Chile             6    4     0     2         10
# 3         4      Yugoslavia             6    3     0     3         10
# 4         5         Hungary             4    2     1     1          8
#
#    Goals Against Goal Difference  Points
# 0              5               9      11
# 1              7               0       7
# 2              8               2       8
# 3              7               3       6
# 4              3               5       5

# %%
print(read1.tail(5))
# Out:
#     Position         Team  Games Played  Win  Draw  Loss  Goals For  \
# 11        12        Spain             3    1     0     2          2
# 12        13      Uruguay             3    1     0     2          4
# 13        14     Colombia             3    0     1     2          5
# 14        15     Bulgaria             3    0     1     2          1
# 15        16  Switzerland             3    0     0     3          2
#
#     Goals Against Goal Difference  Points
# 11              3              −1       2
# 12              6              −2       2
# 13             11              −6       1
# 14              7              −6       1
# 15              8              −6       0

# %%
print(read1.columns)
# Out:
# Index(['Position', 'Team', 'Games Played', 'Win', 'Draw', 'Loss', 'Goals For',
#        'Goals Against', 'Goal Difference', 'Points'],
#       dtype='object')

# %%
maxi_pt=read1["Points"].max()
print(maxi_pt)
# Out:
# 11

# %%
min_pt=read1["Points"].min()
print(min_pt)
# Out:
# 0

# %%
read1.sort_values(["Points"],ascending=False).head(5)
# Out:
#    Position            Team  Games Played  Win  Draw  Loss  Goals For  \
# 0         1          Brazil             6    5     1     0         14
# 2         3           Chile             6    4     0     2         10
# 1         2  Czechoslovakia             6    3     1     2          7
# 3         4      Yugoslavia             6    3     0     3         10
# 4         5         Hungary             4    2     1     1          8
#
#    Goals Against Goal Difference  Points
# 0              5               9      11
# 2              8               2       8
# 1              7               0       7
# 3              7               3       6
# 4              3               5       5

# %%
read1.describe()
# Out:
#         Position  Games Played        Win    Draw     Loss  Goals For  \
# count  16.000000     16.000000  16.000000  16.000  16.0000  16.000000
# mean    8.500000      4.000000   1.687500   0.625   1.6875   5.562500
# std     4.760952      1.264911   1.447699   0.500   0.7932   3.723238
# min     1.000000      3.000000   0.000000   0.000   0.0000   1.000000
# 25%     4.750000      3.000000   1.000000   0.000   1.0000   2.750000
# 50%     8.500000      3.500000   1.000000   1.000   2.0000   4.500000
# 75%    12.250000      4.500000   2.250000   1.000   2.0000   8.250000
# max    16.000000      6.000000   5.000000   1.000   3.0000  14.000000
#
#        Goals Against    Points
# count      16.000000  16.00000
# mean        5.562500   4.00000
# std         2.555223   2.94392
# min         2.000000   0.00000
# 25%         3.000000   2.00000
# 50%         6.000000   3.00000
# 75%         7.000000   5.25000
# max        11.000000  11.00000

# %%
read1.sort_values(["Team","Win"],ascending=[False,False]).head(5)
# Out:
#     Position          Team  Games Played  Win  Draw  Loss  Goals For  \
# 3          4    Yugoslavia             6    3     0     3         10
# 6          7  West Germany             4    2     1     1          4
# 12        13       Uruguay             3    1     0     2          4
# 15        16   Switzerland             3    0     0     3          2
# 11        12         Spain             3    1     0     2          2
#
#     Goals Against Goal Difference  Points
# 3               7               3       6
# 6               2               2       5
# 12              6              −2       2
# 15              8              −6       0
# 11              3              −1       2

# %%
from IPython.display import Image
Image(filename="E:\PY\pandas\download.jpg")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.size'] = 12
plt.figure(figsize=(15,6))
sns.barplot(x="Team",y="Win",data=read1.sort_values(["Team","Points"]).head(10))
plt.xticks(rotation=40)
plt.xlabel("TEAMS")
plt.ylabel("WINS")
plt.title("Data Visualisation")
# Out:
# Text(0.5, 1.0, 'Data Visualisation')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.size'] = 12
plt.figure(figsize=(15,6))
sns.barplot(x="Team",y="Win",data=read1.sort_values(["Team","Win"]).tail(5))
plt.xticks(rotation=40)
plt.xlabel("TEAMS")
plt.ylabel("WINS")
plt.title("Data Visualisation")
# Out:
# Text(0.5, 1.0, 'Data Visualisation')
